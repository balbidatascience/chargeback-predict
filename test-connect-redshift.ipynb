# %%
#!pip install psycopg2

from pandas import DataFrame

# %%
import psycopg2

conn = psycopg2.connect(host='bileto.cn8bpfcjio3s.us-east-1.redshift.amazonaws.com', port='5439', dbname='bileto', user='gabriel.machado.balbi', password='NC9M?A-KuCsN)x=)')
# Out:
# /anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
cur = conn.cursor()

# %%
cur.execute('select * from public.sales limit 10;')

# %%
df = DataFrame(cur.fetchall())

# %%
df.head(10)
# Out:
#           0         1                   2           3           4        5   \
# 0  166931009  11476410 2014-01-01 00:00:33  2014-01-01  2013-12-30  2014-01
# 1  166931011  11476410 2014-01-01 00:00:33  2014-01-01  2013-12-30  2014-01
# 2  166931071  11476410 2014-01-01 00:00:33  2014-01-01  2013-12-30  2014-01
# 3  171597307  11476411 2014-01-01 00:01:58  2014-01-01  2013-12-30  2014-01
# 4  171597308  11476411 2014-01-01 00:01:58  2014-01-01  2013-12-30  2014-01
# 5  169303856  11476412 2014-01-01 00:02:21  2014-01-01  2013-12-30  2014-01
# 6  166934299  11476414 2014-01-01 00:30:45  2014-01-01  2013-12-30  2014-01
# 7  166934298  11476414 2014-01-01 00:30:45  2014-01-01  2013-12-30  2014-01
# 8  166934300  11476414 2014-01-01 00:30:45  2014-01-01  2013-12-30  2014-01
# 9  166934301  11476414 2014-01-01 00:30:45  2014-01-01  2013-12-30  2014-01
#
#         6            7                               8     9   ...   \
# ...

# %%
cur.close()
conn.close()
